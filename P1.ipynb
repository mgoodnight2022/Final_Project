# %%
import requests
import pandas as pd
import json

# %%
res = requests.get("https://api.open-meteo.com/v1/forecast?latitude=40.71&longitude=-74.01&hourly=temperature_2m,precipitation&daily=sunrise,sunset&temperature_unit=fahrenheit&windspeed_unit=mph&precipitation_unit=inch&timezone=America%2FNew_York&past_days=2")

# %%
print(list(res.json()))
# Out:
# ['elevation', 'hourly', 'daily', 'daily_units', 'hourly_units', 'generationtime_ms', 'latitude', 'utc_offset_seconds', 'longitude']

# %%
hourly_json = res.json()
hourly_json["hourly"]
df = pd.DataFrame(hourly_json["hourly"])
print(df)
# Out:
#                  time  precipitation  temperature_2m
# 0    2022-05-04T00:00          0.000            50.4
# 1    2022-05-04T01:00          0.000            50.3
# 2    2022-05-04T02:00          0.000            51.0
# 3    2022-05-04T03:00          0.000            50.7
# 4    2022-05-04T04:00          0.012            51.2
# ..                ...            ...             ...
# 211  2022-05-12T19:00          0.000            62.8
# 212  2022-05-12T20:00          0.000            59.2
# 213  2022-05-12T21:00          0.000            57.5
# 214  2022-05-12T22:00          0.000            56.4
# 215  2022-05-12T23:00          0.000            55.5
#
# [216 rows x 3 columns]
