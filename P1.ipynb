# %%
import requests
import pandas as pd
import json

# %%
res = requests.get("https://api.open-meteo.com/v1/forecast?latitude=40.71&longitude=-74.01&hourly=temperature_2m,precipitation&daily=sunrise,sunset&temperature_unit=fahrenheit&windspeed_unit=mph&precipitation_unit=inch&timezone=America%2FNew_York&past_days=2")

# %%
weather_json = res.json()
weather_json["Weather"]
df = pd.DataFrame(weather_json["Weather"])
display(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7584\1705660913.py in <module>
#       1 weather_json = res.json()
# ----> 2 weather_json["Weather"]
#       3 df = pd.DataFrame(weather_json["Weather"])
#       4 display(df)
#
# KeyError: 'Weather'
